# %%
# Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# Read the dataset
df = pd.read_csv("student_exam_regression_dataset-1.csv")

# %%
# Display first 5 rows
print(df.head())
# Out:
#    Study_Hours  Attendance_Percentage  Assignments_Completed  Sleep_Hours  \
# 0          4.4                     80                      7          6.2
# 1          9.6                     91                      3          4.6
# 2          7.6                     82                      2          5.4
# 3          6.4                     92                     10          5.8
# 4          2.4                     62                      4          7.2
#
#    Exam_Score
# 0       105.2
# 1       130.5
# 2       107.8
# 3       134.8
# 4        66.9

# %%
# Input features
X = df.drop("Exam_Score", axis=1)

# %%
# Target variable
y = df["Exam_Score"]

# %%
# Split dataset into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X,                  # Input features
    y,                  # Target variable
    test_size=0.2,     # 20% testing data
    random_state=42    #Fixed random value
)

# %%
# Create model object
model = LinearRegression()

# %%
# Train model using training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict diamond prices
y_pred = model.predict(X_test)

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)

# %%
# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)

# %%
# Calculate R2 Score
r2 = r2_score(y_test, y_pred)

# %%
print("\nModel Evaluation Results")
# Out:
# Model Evaluation Results

# %%
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 3.5142136572120917

# %%
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 21.32577753310852

# %%
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 4.617984141712542

# %%
print("R2 Score:", r2)
# Out:
# R2 Score: 0.9603532266286442

# %%
# Create comparison table
comparison = pd.DataFrame({
    "Actual Exam Score": y_test,
    "Predicted Exam Score": y_pred
})

# %%
# Display first 10 results
print("\nActual vs Predicted Prices")
# Out:
# Actual vs Predicted Prices

# %%
print(comparison.head(10))
# Out:
#      Actual Exam Score  Predicted Exam Score
# 142              116.6            117.203409
# 6                 76.4             86.029252
# 97               101.7             95.909095
# 60               100.7            106.391487
# 112              133.1            133.476614
# 181               86.7             82.041941
# 197              154.4            151.979763
# 184               99.4            103.246682
# 9                127.0            118.806629
# 104              144.1            143.584170
