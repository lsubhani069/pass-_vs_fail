# %%
# Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
# Read the Excel dataset
df = pd.read_excel('diamond_price_prediction_dataset (1).xlsx')

# %%
# Display first 5 rows
print(df.head())
# Out:
#    Carat  Cut_Score  Color_Score  Clarity_Score  Depth  Table  Length_x  \
# 0   2.00          4            1              5  57.21  55.73     11.76
# 1   4.76          3            2              4  68.90  68.06     17.64
# 2   3.71          1            3              3  62.38  68.00     20.35
# 3   3.07          4            4              3  58.87  66.03     18.07
# 4   0.95          4            5              4  61.89  67.35      4.60
#
#    Width_y  Height_z  Price
# 0    13.24      6.67  30004
# 1    18.70     16.87  62617
# 2    24.28     11.42  49102
# 3    17.39     11.60  45294
# 4     6.98      2.37  18137

# %%
# Input features
X = df.drop("Price", axis=1)

# %%
# Target variable
y = df["Price"]

# %%
# Split dataset into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X,                  # Input features
    y,                  # Target variable
    test_size=0.2,      # 20% testing data
    random_state=42    #Fixed random value
)

# %%
# Create model object
model = LinearRegression()

# %%
# Train model using training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict diamond prices
y_pred = model.predict(X_test)

# %%
# Calculate Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)

# %%
# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)

# %%
# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)

# %%
# Calculate R2 Score
r2 = r2_score(y_test, y_pred)

# %%
print("\nModel Evaluation Results")
# Out:
# Model Evaluation Results

# %%
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 829.9660636433875

# %%
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 1029229.5170615811

# %%
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 1014.509495796654

# %%
print("R2 Score:", r2)
# Out:
# R2 Score: 0.9964102036080298

# %%
# Create comparison table
comparison = pd.DataFrame({
    "Actual Price": y_test,
    "Predicted Price": y_pred
})

# %%
# Display first 10 results
print("\nActual vs Predicted Prices")
# Out:
# Actual vs Predicted Prices

# %%
print(comparison.head(10))
# Out:
#      Actual Price  Predicted Price
# 95          37492     37009.752773
# 15          17186     17000.040803
# 30          45417     43988.127894
# 158         18941     17918.354607
# 128          7480      7698.834880
# 115         61732     62111.221812
# 69          62899     63336.542278
# 170         47190     48731.457994
# 174         44790     46224.122564
# 45          47876     47384.528864
